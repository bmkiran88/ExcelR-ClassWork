# %%
import pandas as pd

# %%
from sklearn import datasets

# %%
boston_house=datasets.load_boston()
boston_house
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#          4.9800e+00],
#         [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#          9.1400e+00],
#         [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#          4.0300e+00],
#         ...,
#         [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          5.6400e+00],
#         [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#          6.4800e+00],
#         [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          7.8800e+00]]),
#  'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#         18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#         15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#         13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
# ...

# %% [markdown]
# ## Data Description
# The Boston data frame has 506 rows and 14 columns.
#
# This data frame contains the following columns:
#
# #### Input variables
# * crim - per capita crime rate by town.
#
# * zn - proportion of residential land zoned for lots over 25,000 sq.ft.
#
# * indus - proportion of non-retail business acres per town.
#
# * chas - Charles River dummy variable (= 1 if tract bounds river; 0 otherwise).
#
# * nox - nitrogen oxides concentration (parts per 10 million).
#
# * rm - average number of rooms per dwelling.
#
# * age - proportion of owner-occupied units built prior to 1940.
#
# * dis - weighted mean of distances to five Boston employment centres.
#
# * rad - index of accessibility to radial highways.
#
# * tax - full-value property-tax rate per \$10,000.
#
# * ptratio - pupil-teacher ratio by town.
#
# * black 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town.
#
# * lstat -lower status of the population (percent).
#
# ##### Target Variable
#
# * medv -median value of owner-occupied homes in \$1000s.

# %%
house_data=pd.DataFrame(boston_house.data,columns=boston_house.feature_names)
house_data['TARGET']=boston_house.target
house_data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  TARGET
# 0       15.3  396.90   4.98    24.0
# ...

# %%
house_data.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# TARGET     0
# dtype: int64

# %%
house_data.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD        float64
# TAX        float64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# TARGET     float64
# dtype: object

# %%
house_data.mean()
# Out:
# CRIM         3.613524
# ZN          11.363636
# INDUS       11.136779
# CHAS         0.069170
# NOX          0.554695
# RM           6.284634
# AGE         68.574901
# DIS          3.795043
# RAD          9.549407
# TAX        408.237154
# PTRATIO     18.455534
# B          356.674032
# LSTAT       12.653063
# TARGET      22.532806
# dtype: float64

# %%
house_data.std()
# Out:
# CRIM         8.601545
# ZN          23.322453
# INDUS        6.860353
# CHAS         0.253994
# NOX          0.115878
# RM           0.702617
# AGE         28.148861
# DIS          2.105710
# RAD          8.707259
# TAX        168.537116
# PTRATIO      2.164946
# B           91.294864
# LSTAT        7.141062
# TARGET       9.197104
# dtype: float64

# %%
import matplotlib.pyplot as plt
plt.hist(house_data.RM)
# Out:
# (array([  2.,   4.,  14.,  45., 177., 151.,  69.,  22.,  13.,   9.]),
#  array([3.561 , 4.0829, 4.6048, 5.1267, 5.6486, 6.1705, 6.6924, 7.2143,
#         7.7362, 8.2581, 8.78  ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Model Building

# %%
X=house_data.iloc[:,:-1]
y=house_data[['TARGET']]

# %% [markdown]
# ## Model Training, Testing and Evaluation with Cross Validation

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score 

linear_model=LinearRegression()
cv_score=cross_val_score(estimator=linear_model,X=X,y=y,cv=5)
print('The CV Score for the above model:{}\nMean Accuracy:{}\nStd Deviation:{}.'.format(cv_score,cv_score.mean(),cv_score.std()))
# Out:
# The CV Score for the above model:[ 0.63919994  0.71386698  0.58702344  0.07923081 -0.25294154]
# Mean Accuracy:0.353275924395883
# Std Deviation:0.37656783933261584.

# %% [markdown]
# ## Model Optimization

# %% [markdown]
# ##### 1. Standard Scaler - Mean = 0, STD =1

# %%
from sklearn.preprocessing import StandardScaler
std_scaler=StandardScaler()
std_scaler=std_scaler.fit_transform(house_data)

# %%
std_scaled_house_dataset=pd.DataFrame(std_scaler,index=house_data.index, columns=house_data.columns)
std_scaled_house_dataset.head()
# Out:
#        CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0 -0.419782  0.284830 -1.287909 -0.272599 -0.144217  0.413672 -0.120013
# 1 -0.417339 -0.487722 -0.593381 -0.272599 -0.740262  0.194274  0.367166
# 2 -0.417342 -0.487722 -0.593381 -0.272599 -0.740262  1.282714 -0.265812
# 3 -0.416750 -0.487722 -1.306878 -0.272599 -0.835284  1.016303 -0.809889
# 4 -0.412482 -0.487722 -1.306878 -0.272599 -0.835284  1.228577 -0.511180
#
#         DIS       RAD       TAX   PTRATIO         B     LSTAT    TARGET
# 0  0.140214 -0.982843 -0.666608 -1.459000  0.441052 -1.075562  0.159686
# 1  0.557160 -0.867883 -0.987329 -0.303094  0.441052 -0.492439 -0.101524
# 2  0.557160 -0.867883 -0.987329 -0.303094  0.396427 -1.208727  1.324247
# 3  1.077737 -0.752922 -1.106115  0.113032  0.416163 -1.361517  1.182758
# 4  1.077737 -0.752922 -1.106115  0.113032  0.441052 -1.026501  1.487503

# %%
std_scaled_house_dataset.mean()
# Out:
# CRIM      -8.513173e-17
# ZN         3.306534e-16
# INDUS      2.804081e-16
# CHAS      -3.100287e-16
# NOX       -8.071058e-16
# RM        -5.189086e-17
# AGE       -2.650493e-16
# DIS        8.293761e-17
# RAD        1.514379e-15
# TAX       -9.934960e-16
# PTRATIO    4.493551e-16
# B         -1.451408e-16
# LSTAT     -1.595123e-16
# TARGET    -4.247810e-16
# dtype: float64

# %%
std_scaled_house_dataset.std()
# Out:
# CRIM       1.00099
# ZN         1.00099
# INDUS      1.00099
# CHAS       1.00099
# NOX        1.00099
# RM         1.00099
# AGE        1.00099
# DIS        1.00099
# RAD        1.00099
# TAX        1.00099
# PTRATIO    1.00099
# B          1.00099
# LSTAT      1.00099
# TARGET     1.00099
# dtype: float64

# %%
X_std=std_scaled_house_dataset.iloc[:,:-1]
y_std=std_scaled_house_dataset[['TARGET']]

# %%
X_std
# Out:
#          CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0   -0.419782  0.284830 -1.287909 -0.272599 -0.144217  0.413672 -0.120013
# 1   -0.417339 -0.487722 -0.593381 -0.272599 -0.740262  0.194274  0.367166
# 2   -0.417342 -0.487722 -0.593381 -0.272599 -0.740262  1.282714 -0.265812
# 3   -0.416750 -0.487722 -1.306878 -0.272599 -0.835284  1.016303 -0.809889
# 4   -0.412482 -0.487722 -1.306878 -0.272599 -0.835284  1.228577 -0.511180
# ..        ...       ...       ...       ...       ...       ...       ...
# 501 -0.413229 -0.487722  0.115738 -0.272599  0.158124  0.439316  0.018673
# 502 -0.415249 -0.487722  0.115738 -0.272599  0.158124 -0.234548  0.288933
# 503 -0.413447 -0.487722  0.115738 -0.272599  0.158124  0.984960  0.797449
# 504 -0.407764 -0.487722  0.115738 -0.272599  0.158124  0.725672  0.736996
# 505 -0.415000 -0.487722  0.115738 -0.272599  0.158124 -0.362767  0.434732
#
#           DIS       RAD       TAX   PTRATIO         B     LSTAT
# ...

# %%
y_std
# Out:
#        TARGET
# 0    0.159686
# 1   -0.101524
# 2    1.324247
# 3    1.182758
# 4    1.487503
# ..        ...
# 501 -0.014454
# 502 -0.210362
# 503  0.148802
# 504 -0.057989
# 505 -1.157248
#
# [506 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score 

linear_model=LinearRegression()
cv_score_std=cross_val_score(estimator=linear_model,X=X_std,y=y_std,cv=5)
print('The CV Score for the above model:{}\nMean Accuracy:{}\nStd Deviation:{}.'.format(cv_score_std,cv_score_std.mean(),cv_score_std.std()))
# Out:
# The CV Score for the above model:[ 0.63919994  0.71386698  0.58702344  0.07923081 -0.25294154]
# Mean Accuracy:0.35327592439588246
# Std Deviation:0.37656783933262306.

# %% [markdown]
# #### 2. MinMax Scaler - All the values will be between 0 to 1.

# %%
from sklearn.preprocessing import MinMaxScaler
mm_scaler=MinMaxScaler()
mm_scaler=mm_scaler.fit_transform(house_data)

# %%
mm_scaled_data=pd.DataFrame(mm_scaler,columns=house_data.columns)
mm_scaled_data
# Out:
#          CRIM    ZN     INDUS  CHAS       NOX        RM       AGE       DIS  \
# 0    0.000000  0.18  0.067815   0.0  0.314815  0.577505  0.641607  0.269203
# 1    0.000236  0.00  0.242302   0.0  0.172840  0.547998  0.782698  0.348962
# 2    0.000236  0.00  0.242302   0.0  0.172840  0.694386  0.599382  0.348962
# 3    0.000293  0.00  0.063050   0.0  0.150206  0.658555  0.441813  0.448545
# 4    0.000705  0.00  0.063050   0.0  0.150206  0.687105  0.528321  0.448545
# ..        ...   ...       ...   ...       ...       ...       ...       ...
# 501  0.000633  0.00  0.420455   0.0  0.386831  0.580954  0.681771  0.122671
# 502  0.000438  0.00  0.420455   0.0  0.386831  0.490324  0.760041  0.105293
# 503  0.000612  0.00  0.420455   0.0  0.386831  0.654340  0.907312  0.094381
# 504  0.001161  0.00  0.420455   0.0  0.386831  0.619467  0.889804  0.114514
# 505  0.000462  0.00  0.420455   0.0  0.386831  0.473079  0.802266  0.125072
#
# ...

# %%
mm_scaled_data.mean()
# Out:
# CRIM       0.040544
# ZN         0.113636
# INDUS      0.391378
# CHAS       0.069170
# NOX        0.349167
# RM         0.521869
# AGE        0.676364
# DIS        0.242381
# RAD        0.371713
# TAX        0.422208
# PTRATIO    0.622929
# B          0.898568
# LSTAT      0.301409
# TARGET     0.389618
# dtype: float64

# %%
mm_scaled_data.std()
# Out:
# CRIM       0.096679
# ZN         0.233225
# INDUS      0.251479
# CHAS       0.253994
# NOX        0.238431
# RM         0.134627
# AGE        0.289896
# DIS        0.191482
# RAD        0.378576
# TAX        0.321636
# PTRATIO    0.230313
# B          0.230205
# LSTAT      0.197049
# TARGET     0.204380
# dtype: float64

# %%
X_mm=mm_scaled_data.iloc[:,:-1]
y_mm=mm_scaled_data[['TARGET']]

# %%
X_mm
# Out:
#          CRIM    ZN     INDUS  CHAS       NOX        RM       AGE       DIS  \
# 0    0.000000  0.18  0.067815   0.0  0.314815  0.577505  0.641607  0.269203
# 1    0.000236  0.00  0.242302   0.0  0.172840  0.547998  0.782698  0.348962
# 2    0.000236  0.00  0.242302   0.0  0.172840  0.694386  0.599382  0.348962
# 3    0.000293  0.00  0.063050   0.0  0.150206  0.658555  0.441813  0.448545
# 4    0.000705  0.00  0.063050   0.0  0.150206  0.687105  0.528321  0.448545
# ..        ...   ...       ...   ...       ...       ...       ...       ...
# 501  0.000633  0.00  0.420455   0.0  0.386831  0.580954  0.681771  0.122671
# 502  0.000438  0.00  0.420455   0.0  0.386831  0.490324  0.760041  0.105293
# 503  0.000612  0.00  0.420455   0.0  0.386831  0.654340  0.907312  0.094381
# 504  0.001161  0.00  0.420455   0.0  0.386831  0.619467  0.889804  0.114514
# 505  0.000462  0.00  0.420455   0.0  0.386831  0.473079  0.802266  0.125072
#
#           RAD       TAX   PTRATIO         B     LSTAT
# ...

# %%
y_mm
# Out:
#        TARGET
# 0    0.422222
# 1    0.368889
# 2    0.660000
# 3    0.631111
# 4    0.693333
# ..        ...
# 501  0.386667
# 502  0.346667
# 503  0.420000
# 504  0.377778
# 505  0.153333
#
# [506 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score 

linear_model=LinearRegression()
cv_score_mm=cross_val_score(estimator=linear_model,X=X_mm,y=y_mm,cv=5)
print('The CV Score is:{}\nMean:{}\nStd Dev:{}'.format(cv_score_mm,cv_score_mm.mean(),cv_score_mm.std()))
# Out:
# The CV Score is:[ 0.63919994  0.71386698  0.58702344  0.07923081 -0.25294154]
# Mean:0.3532759243958819
# Std Dev:0.37656783933262306

# %% [markdown]
# #### 3. Robust Scaler

# %%
from sklearn.preprocessing import RobustScaler

rs_scaler=RobustScaler()
rs_scaler=rs_scaler.fit_transform(house_data)

# %%
rs_scaled_data=pd.DataFrame(rs_scaler,columns=house_data.columns)

# %%
rs_scaled_data.mean()
# Out:
# CRIM       0.933791
# ZN         0.909091
# INDUS      0.112067
# CHAS       0.069170
# NOX        0.095400
# RM         0.103163
# AGE       -0.181959
# DIS        0.190267
# RAD        0.227470
# TAX        0.202163
# PTRATIO   -0.212309
# B         -1.667632
# LSTAT      0.129242
# TARGET     0.167123
# dtype: float64

# %%
rs_scaled_data.std()
# Out:
# CRIM       2.392616
# ZN         1.865796
# INDUS      0.531398
# CHAS       0.253994
# NOX        0.662158
# RM         0.952056
# AGE        0.573881
# DIS        0.681846
# RAD        0.435363
# TAX        0.435496
# PTRATIO    0.773195
# B          4.379176
# LSTAT      0.713749
# TARGET     1.153242
# dtype: float64

# %%
X_rs=rs_scaled_data.iloc[:,:-1]
y_rs=rs_scaled_data[['TARGET']]

# %%
X_rs
# Out:
#          CRIM    ZN     INDUS  CHAS       NOX        RM       AGE       DIS  \
# 0   -0.069593  1.44 -0.571650   0.0  0.000000  0.496612 -0.250765  0.285777
# 1   -0.063755  0.00 -0.202943   0.0 -0.394286  0.287940  0.028542  0.569789
# 2   -0.063760  0.00 -0.202943   0.0 -0.394286  1.323171 -0.334353  0.569789
# 3   -0.062347  0.00 -0.581720   0.0 -0.457143  1.069783 -0.646279  0.924391
# 4   -0.052144  0.00 -0.581720   0.0 -0.457143  1.271680 -0.475025  0.924391
# ..        ...   ...       ...   ...       ...       ...       ...       ...
# 501 -0.053930  0.00  0.173509   0.0  0.200000  0.521003 -0.171254 -0.236007
# 502 -0.058759  0.00  0.173509   0.0  0.200000 -0.119919 -0.016310 -0.297887
# 503 -0.054450  0.00  0.173509   0.0  0.200000  1.039973  0.275229 -0.336744
# 504 -0.040867  0.00  0.173509   0.0  0.200000  0.793360  0.240571 -0.265053
# 505 -0.058164  0.00  0.173509   0.0  0.200000 -0.241870  0.067278 -0.227459
#
#       RAD       TAX   PTRATIO         B     LSTAT
# ...

# %%
y_rs
# Out:
#        TARGET
# 0    0.351097
# 1    0.050157
# 2    1.692790
# 3    1.529781
# 4    1.880878
# ..        ...
# 501  0.150470
# 502 -0.075235
# 503  0.338558
# 504  0.100313
# 505 -1.166144
#
# [506 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

linear_model=LinearRegression()
cv_score_rs=cross_val_score(estimator=linear_model,X=X_rs,y=y_rs,cv=5)
print('The CV Score for the above model is:{}\nMean Accuracy:{}\nStd Deviation:{}'.format(cv_score_rs,cv_score_rs.mean(),cv_score_rs.std()))
# Out:
# The CV Score for the above model is:[ 0.63919994  0.71386698  0.58702344  0.07923081 -0.25294154]
# Mean Accuracy:0.3532759243958814
# Std Deviation:0.37656783933262356
