# %% [markdown]
# ## Chapter 3 - Grouping

# %%
import pandas as pd

# %%
drinks_data=pd.read_csv('drinks.csv')
drinks_data.head(20)
# Out:
#               country  beer_servings  spirit_servings  wine_servings  \
# 0         Afghanistan              0                0              0
# 1             Albania             89              132             54
# 2             Algeria             25                0             14
# 3             Andorra            245              138            312
# 4              Angola            217               57             45
# 5   Antigua & Barbuda            102              128             45
# 6           Argentina            193               25            221
# 7             Armenia             21              179             11
# 8           Australia            261               72            212
# 9             Austria            279               75            191
# 10         Azerbaijan             21               46              5
# 11            Bahamas            122              176             51
# 12            Bahrain             42               63              7
# ...

# %% [markdown]
# ## Perform Initial Analysis

# %%
drinks_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     170 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
drinks_data.describe(include='all')
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# count              193     193.000000       193.000000     193.000000
# unique             193            NaN              NaN            NaN
# top     United Kingdom            NaN              NaN            NaN
# freq                 1            NaN              NaN            NaN
# mean               NaN     106.160622        80.994819      49.450777
# std                NaN     101.143103        88.284312      79.697598
# min                NaN       0.000000         0.000000       0.000000
# 25%                NaN      20.000000         4.000000       1.000000
# 50%                NaN      76.000000        56.000000       8.000000
# 75%                NaN     188.000000       128.000000      59.000000
# max                NaN     376.000000       438.000000     370.000000
#
#         total_litres_of_pure_alcohol continent
# count                     193.000000       170
# ...

# %%
drinks_data.isnull().sum()
# Out:
# country                          0
# beer_servings                    0
# spirit_servings                  0
# wine_servings                    0
# total_litres_of_pure_alcohol     0
# continent                       23
# dtype: int64

# %%
drinks_data.shape
# Out:
# (193, 6)

# %%
drinks_data.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
drinks_data.continent.nunique()
# Out:
# 5

# %% [markdown]
# ## 2. On an Avg which continent drinks more beer

# %%
round(drinks_data.groupby('continent')['beer_servings'].mean()).sort_values(ascending=False).head(1)
# Out:
# continent
# EU    194.0
# Name: beer_servings, dtype: float64

# %%
drinks_data.groupby(['continent','country'])['beer_servings'].mean().sort_values(ascending=False).head(1)
# Out:
# continent  country
# AF         Namibia    376
# Name: beer_servings, dtype: int64

# %% [markdown]
# ## -----------------------------------------------

# %% [markdown]
# ##

# %%
import pandas as pd

# %%
user_data=pd.read_csv('u.user',sep='|')
user_data
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %% [markdown]
# ## 1. How many different occupation is available in dataset?

# %%
user_data.occupation.nunique()
# Out:
# 21

# %%
user_data.describe(include='all')
# Out:
#            user_id         age gender occupation zip_code
# count   943.000000  943.000000    943        943      943
# unique         NaN         NaN      2         21      795
# top            NaN         NaN      M    student    55414
# freq           NaN         NaN    670        196        9
# mean    472.000000   34.051962    NaN        NaN      NaN
# std     272.364951   12.192740    NaN        NaN      NaN
# min       1.000000    7.000000    NaN        NaN      NaN
# 25%     236.500000   25.000000    NaN        NaN      NaN
# 50%     472.000000   31.000000    NaN        NaN      NaN
# 75%     707.500000   43.000000    NaN        NaN      NaN
# max     943.000000   73.000000    NaN        NaN      NaN

# %% [markdown]
# ## 2. Discover the mean age of occupation?

# %%
round(user_data.groupby(['occupation'])['age'].mean()).sort_values(ascending=False)
# Out:
# occupation
# retired          63.0
# doctor           44.0
# educator         42.0
# healthcare       42.0
# librarian        40.0
# executive        39.0
# administrator    39.0
# marketing        38.0
# lawyer           37.0
# engineer         36.0
# salesman         36.0
# scientist        36.0
# writer           36.0
# other            35.0
# homemaker        33.0
# programmer       33.0
# technician       33.0
# artist           31.0
# entertainment    29.0
# none             27.0
# student          22.0
# Name: age, dtype: float64

# %% [markdown]
# ## 3 For each combination of occupation and gender, what is the average age?

# %%
round(user_data.groupby(['occupation','gender'])['age'].mean()).sort_values(ascending=False)
# Out:
# occupation     gender
# retired        F         70.0
#                M         63.0
# healthcare     M         45.0
# executive      F         44.0
# doctor         M         44.0
# educator       M         43.0
# administrator  F         41.0
# librarian      F         40.0
# lawyer         F         40.0
# healthcare     F         40.0
# librarian      M         40.0
# salesman       M         39.0
# educator       F         39.0
# writer         F         38.0
# technician     F         38.0
# marketing      M         38.0
# executive      M         38.0
# engineer       M         37.0
# administrator  M         37.0
# marketing      F         37.0
# scientist      M         36.0
# lawyer         M         36.0
# none           F         36.0
# writer         M         35.0
# other          F         35.0
#                M         34.0
# homemaker      F         34.0
# programmer     M         33.0
# technician     M         33.0
# programmer     F         32.0
# ...

# %% [markdown]
# ### Lambda Functions

# %%
import pandas as pd

# %%
student_details=pd.read_csv('student-mat.csv')
student_details.head(20)
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0      GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1      GP   F   17       U     GT3       T     1     1   at_home     other
# 2      GP   F   15       U     LE3       T     1     1   at_home     other
# 3      GP   F   15       U     GT3       T     4     2    health  services
# 4      GP   F   16       U     GT3       T     3     3     other     other
# 5      GP   M   16       U     LE3       T     4     3  services     other
# 6      GP   M   16       U     LE3       T     2     2     other     other
# 7      GP   F   17       U     GT3       A     4     4     other   teacher
# 8      GP   M   15       U     LE3       A     3     2  services     other
# 9      GP   M   15       U     GT3       T     3     4     other     other
# 10     GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %%
student_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
student_details.shape
# Out:
# (395, 33)

# %%
student_details.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
student_details.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %% [markdown]
# ## 1. Filter the data set from School till Guardian

# %%
student_details.iloc[:,:12]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      reason guardian
# 0    course   mother
# ...

# %% [markdown]
# ##  OR

# %%
student_guardian=student_details.loc[:,'school':'guardian']
student_guardian
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %%
pd.set_option('max_rows',None)

# %% [markdown]
# ## Multiply the age by 2
# * Noraml functions are defined using def keyword and anonymous fn are used by using lambda functions
#
# * lambda x,y:x*y lambda is dataset age is x

# %%
student_guardian['age']=student_guardian.age.apply(lambda x:x*2)

# %%
student_guardian
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   36       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   34       U     GT3       T     1     1   at_home     other
# 2       GP   F   30       U     LE3       T     1     1   at_home     other
# 3       GP   F   30       U     GT3       T     4     2    health  services
# 4       GP   F   32       U     GT3       T     3     3     other     other
# 5       GP   M   32       U     LE3       T     4     3  services     other
# 6       GP   M   32       U     LE3       T     2     2     other     other
# 7       GP   F   34       U     GT3       A     4     4     other   teacher
# 8       GP   M   30       U     LE3       A     3     2  services     other
# 9       GP   M   30       U     GT3       T     3     4     other     other
# 10      GP   F   30       U     GT3       T     4     4   teacher    health
# ...

# %%
len('abcd1') # predefined
# Out:
# 5

# %%
def get_input(x): #user defined
    print(x*2)
get_input(4)
# Out:
# 8

# %% [markdown]
# ## 3. Use lambda function and Capitalize guardian and Fjob

# %%
student_guardian['guardian']=student_guardian.guardian.apply(lambda x:x.capitalize())
student_guardian['Fjob']=student_guardian.Fjob.apply(lambda x:x.capitalize())

# %%
student_guardian.head(20)
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0      GP   F   36       U     GT3       A     4     4   at_home   Teacher
# 1      GP   F   34       U     GT3       T     1     1   at_home     Other
# 2      GP   F   30       U     LE3       T     1     1   at_home     Other
# 3      GP   F   30       U     GT3       T     4     2    health  Services
# 4      GP   F   32       U     GT3       T     3     3     other     Other
# 5      GP   M   32       U     LE3       T     4     3  services     Other
# 6      GP   M   32       U     LE3       T     2     2     other     Other
# 7      GP   F   34       U     GT3       A     4     4     other   Teacher
# 8      GP   M   30       U     LE3       A     3     2  services     Other
# 9      GP   M   30       U     GT3       T     3     4     other     Other
# 10     GP   F   30       U     GT3       T     4     4   teacher    Health
# ...

# %% [markdown]
# ## 4. Create a function called major that returns a boolean value to a new column 'legal drinker'.
#
# #### Note: the age eligibility is 17

# %%
def major(x):
    if x>=17:
        return True
    else:
        return False
    
student_guardian['legal_drinker']=student_guardian.age.apply(lambda x:major(x))
student_guardian
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %% [markdown]
# ### OR

# %%
student_guardian['legal_drinker']=student_guardian.age.apply(lambda x:x>=17)
student_guardian
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %%
def major(x):
    if x>=17:
        return True
    else:
        return False
    
student_guardian['legal_drinker']=student_guardian.age.apply(major)
student_guardian
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %% [markdown]
# ### 21/07/2021

# %% [markdown]
# ### Chapter 05 - Merge

# %%
import pandas as pd

# %%
sales_2017=pd.read_csv('Sales Transactions-2017.csv')
sales_2018=pd.read_csv('Sales Transactions-2018.csv')
sales_2019=pd.read_csv('Sales Transactions-2019.csv')

# %%
sales_2017.head()
# Out:
#        Date Voucher               Party            Product  Qty      Rate  \
# 0  1/4/2017   Sal:1    SOLANKI PLASTICS      DONA-VAI-9100    2  1,690.00
# 1  1/4/2017   Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)    6  1,620.00
# 2  1/4/2017   Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE  500        23
# 3  1/4/2017   Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)    6  1,620.00
# 4  1/4/2017   Sal:2  SARNESWARA TRADERS      DONA-VAI-9100    5  1,690.00
#
#        Gross Disc Voucher Amount
# 0   3,380.00  NaN      13,100.00
# 1   9,720.00  NaN            NaN
# 2  11,500.00  NaN      30,990.00
# 3   9,720.00  NaN            NaN
# 4   8,450.00  NaN            NaN

# %%
sales_2018.head()
# Out:
#        Date  Voucher Party            Product       Qty Rate     Gross Disc  \
# 0  1/4/2018  Sal:146  TP13  SILVER POUCH 9*12        50   85  4,250.00  NaN
# 1  1/4/2018  Sal:146  TP13             RUBBER         5  290  1,450.00  NaN
# 2  1/4/2018  Sal:146  TP13   DURGA 10*12 Blue  1,600.00  5.5  8,800.00  NaN
# 3  1/4/2018  Sal:146  TP13   DURGA 13*16 BLUE       400   11  4,400.00  NaN
# 4  1/4/2018  Sal:146  TP13    10*12 SARAS-NAT       600  8.1  4,860.00  NaN
#
#   Voucher Amount
# 0      66,724.00
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
sales_2019.head()
# Out:
#        Date  Voucher            Party         Product  Qty      Rate  \
# 0  1/4/2019  Sal:687  BALAJI PLASTICS   DONA-VAI-9100    1  1,730.00
# 1  1/4/2019  Sal:687  BALAJI PLASTICS  SMART BOUL(48)    1  1,730.00
# 2  1/4/2019  Sal:688  BALAJI PLASTICS      Vishnu Ice  110      18.5
# 3                                28/3                    0         0
# 4  1/4/2019  Sal:689  BALAJI PLASTICS     100LEAF -SP    3       585
#
#       Gross Disc Voucher Amount
# 0  1,730.00  NaN       3,460.00
# 1  1,730.00  NaN            NaN
# 2  2,035.00  NaN       2,035.00
# 3
# 4  1,755.00  NaN       1,755.00

# %% [markdown]
# ##    1. Concotenate all 3 dataset into one dataframe

# %%
sales_full_data=pd.concat([sales_2017,sales_2018,sales_2019])
sales_full_data.head(200)
# Out:
#          Date   Voucher                Party              Product       Qty  \
# 0    1/4/2017     Sal:1     SOLANKI PLASTICS        DONA-VAI-9100         2
# 1    1/4/2017     Sal:1     SOLANKI PLASTICS      LITE FOAM(1200)         6
# 2    1/4/2017     Sal:2   SARNESWARA TRADERS    VISHNU CHOTA WINE       500
# 3    1/4/2017     Sal:2   SARNESWARA TRADERS      LITE FOAM(1200)         6
# 4    1/4/2017     Sal:2   SARNESWARA TRADERS        DONA-VAI-9100         5
# 5    1/4/2017     Sal:2   SARNESWARA TRADERS   CLASSIC ENJOY(750)         1
# 6    1/4/2017   Sal:898                 Lock         Vishnu 250ml       100
# 7    1/4/2017   Sal:898                 Lock      BLACK DOG-350ML       100
# 8                        khader vali late en
# 9                                        try
# 10   1/4/2017  Sal:2497  VAMSI KRISHNA FANCY          Loose Items         1
# 11        NaN       NaN               #NAME?                  NaN       NaN
# ...

# %%
pd.set_option('max_rows',None)

# %% [markdown]
# ### OR

# %%
sales_2017.append([sales_2018,sales_2019])
# Out:
#              Date   Voucher               Party            Product  \
# 0        1/4/2017     Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017     Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017     Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017     Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017     Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...       ...                 ...                ...
# 19171  10/10/2019  Sal:4935           K.SRIHARI     13*16 WHITE RK
# 19172         NaN       NaN                 NaN                NaN
# 19173         NaN       NaN                 NaN                NaN
# 19174         NaN   Total                   NaN                NaN
# 19175         NaN   Total                   NaN                NaN
#
#                 Qty          Rate          Gross        Disc Voucher Amount
# 0                 2      1,690.00       3,380.00         NaN      13,100.00
# ...

# %%
sales_full_data.dtypes
# Out:
# Date              object
# Voucher           object
# Party             object
# Product           object
# Qty               object
# Rate              object
# Gross             object
# Disc              object
# Voucher Amount    object
# dtype: object

# %%
sales_full_data.isnull().sum()
# Out:
# Date               12591
# Voucher            12557
# Party                 40
# Product            12591
# Qty                12557
# Rate               12558
# Gross              12558
# Disc              105609
# Voucher Amount     83646
# dtype: int64

# %%
#Assignment for today:
Date              datetime64
Voucher           int64
Party             object
Product           object
Qty               int64
Rate              float64

# %%
type(sales_full_data['Date'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Chapter 6-  Delete

# %%
import pandas as pd

# %%
drinks_data=pd.read_csv('drinks.csv')

# %%
drinks_data
# Out:
#                           country  beer_servings  spirit_servings  \
# 0                     Afghanistan              0                0
# 1                         Albania             89              132
# 2                         Algeria             25                0
# 3                         Andorra            245              138
# 4                          Angola            217               57
# 5               Antigua & Barbuda            102              128
# 6                       Argentina            193               25
# 7                         Armenia             21              179
# 8                       Australia            261               72
# 9                         Austria            279               75
# 10                     Azerbaijan             21               46
# 11                        Bahamas            122              176
# 12                        Bahrain             42               63
# ...

# %%
drinks_data.isnull().sum()
# Out:
# country                          0
# beer_servings                    0
# spirit_servings                  0
# wine_servings                    0
# total_litres_of_pure_alcohol     0
# continent                       23
# dtype: int64

# %% [markdown]
# ### 1st Method

# %%
del drinks_data['continent']

# %%
drinks_data.head(20)
# Out:
#               country  beer_servings  spirit_servings  wine_servings  \
# 0         Afghanistan              0                0              0
# 1             Albania             89              132             54
# 2             Algeria             25                0             14
# 3             Andorra            245              138            312
# 4              Angola            217               57             45
# 5   Antigua & Barbuda            102              128             45
# 6           Argentina            193               25            221
# 7             Armenia             21              179             11
# 8           Australia            261               72            212
# 9             Austria            279               75            191
# 10         Azerbaijan             21               46              5
# 11            Bahamas            122              176             51
# 12            Bahrain             42               63              7
# ...

# %% [markdown]
# ### 2nd Method

# %%
drinks_data.drop(labels=['continent','country'],axis=1)
# Out:
#      beer_servings  spirit_servings  wine_servings  \
# 0                0                0              0
# 1               89              132             54
# 2               25                0             14
# 3              245              138            312
# 4              217               57             45
# 5              102              128             45
# 6              193               25            221
# 7               21              179             11
# 8              261               72            212
# 9              279               75            191
# 10              21               46              5
# 11             122              176             51
# 12              42               63              7
# 13               0                0              0
# 14             143              173             36
# 15             142              373             42
# 16             295               84            212
# ...

# %% [markdown]
# ###  or

# %%
drinks_data.drop(labels=['continent','country'],axis=1,inplace=False)
#inplace=True for affecting the original dataset
# Out:
#      beer_servings  spirit_servings  wine_servings  \
# 0                0                0              0
# 1               89              132             54
# 2               25                0             14
# 3              245              138            312
# 4              217               57             45
# 5              102              128             45
# 6              193               25            221
# 7               21              179             11
# 8              261               72            212
# 9              279               75            191
# 10              21               46              5
# 11             122              176             51
# 12              42               63              7
# 13               0                0              0
# 14             143              173             36
# 15             142              373             42
# 16             295               84            212
# ...

# %% [markdown]
# ## -----------------------------------------------------

# %% [markdown]
# ### Chapter 07-Creaing Series and Dataframes
#
# In Pandas we have Series and Dataframe
#
# * Series - 1D datastructure of Pandas,i.e., one row.
# * Dataframe - 2D datastructure of Pandas, i.e, row and column

# %%
runs=pd.Series([12,34,45])
runs
# Out:
# 0    12
# 1    34
# 2    45
# dtype: int64

# %%
type(runs)
# Out:
# pandas.core.series.Series

# %%
learner_details = pd.DataFrame(
    {'Fname': ['Manan', 'Kumar'], 'Lname': ['Malhotra', 'Prince']})
learner_details
# Out:
#    Fname     Lname
# 0  Manan  Malhotra
# 1  Kumar    Prince

# %%
type(learner_details)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### --------------------------------------------------------------------

# %% [markdown]
# ### Chapter 12- Grouping Vs Pivottable Vs Crosstab

# %%
import pandas as pd

# %%
insurance_data=pd.read_csv('insurance.csv')
insurance_data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
insurance_data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# ### Hint to apply groupby fn in any dataset

# %%
insurance_data.sex.unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
insurance_data.children.unique()
# Out:
# array([0, 1, 3, 2, 5, 4], dtype=int64)

# %%
insurance_data.region.unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
insurance_data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
insurance_data.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %% [markdown]
# ##  Get the regionwise average insurance charges

# %%
round(insurance_data.groupby('region')['charges'].mean())
# Out:
# region
# northeast    13406.0
# northwest    12418.0
# southeast    14735.0
# southwest    12347.0
# Name: charges, dtype: float64

# %% [markdown]
# ## Get Region and sexwise average insurance charges

# %%
round(insurance_data.groupby(['region','sex'])['charges'].mean())
# Out:
# region     sex
# northeast  female    12953.0
#            male      13854.0
# northwest  female    12480.0
#            male      12354.0
# southeast  female    13500.0
#            male      15880.0
# southwest  female    11274.0
#            male      13413.0
# Name: charges, dtype: float64

# %% [markdown]
# ### Pivot Table
# * same as groupby

# %%
region_wise_insurance_charges=insurance_data[['region','sex','charges','children']]
pd.pivot_table(region_wise_insurance_charges ,values='charges',index='children',columns='region',aggfunc='mean')
# Out:
# region       northeast     northwest     southeast     southwest
# children
# 0         11626.462658  11324.370919  14309.868378  11938.504986
# 1         16310.206403  10230.256309  13687.041971  10406.484953
# 2         13615.152722  13464.314687  15728.470623  17483.485559
# 3         14409.913296  17786.160672  18449.846015  10402.442259
# 4         14485.193120  11347.018725  14451.023972  14933.260533
# 5          6978.973483   8965.795750  10115.441542   8444.158625

# %% [markdown]
# ###  Cross Table
# * it explains the frequency of occurrence of the categorical data we give as index

# %%
pd.crosstab(index=insurance_data.region,columns=insurance_data.sex,margins=True)
# Out:
# sex        female  male   All
# region
# northeast     161   163   324
# northwest     164   161   325
# southeast     175   189   364
# southwest     162   163   325
# All           662   676  1338

# %%
pd.crosstab(index=insurance_data.sex,columns=insurance_data.children,margins=True)
# Out:
# children    0    1    2    3   4   5   All
# sex
# female    289  158  119   77  11   8   662
# male      285  166  121   80  14  10   676
# All       574  324  240  157  25  18  1338

# %%
#groupby and Pivot table=categories and numbers
#crosstab=categories--> It returns the number of occurances
